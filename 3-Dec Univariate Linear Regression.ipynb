# %% [markdown]
# # Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

#Loading datasets

diabetes = datasets.load_diabetes()

print(diabetes.keys())

print(diabetes.DESCR)

#Set single feature and index

diabetes_X = diabetes.data[:, np.newaxis, 2]

#Setting training and testing data

diabetes_X_train = diabetes_X[:-30]
diabetes_X_test = diabetes_X[-30:]

diabetes_Y_train = diabetes.target[:-30]
diabetes_Y_test = diabetes.target[-30:]

#Making linear model

model = linear_model.LinearRegression()

#Fitting model

model.fit(diabetes_X_train, diabetes_Y_train)

#Predicting

diabetes_Y_predicted = model.predict(diabetes_X_test)

#Getting MSE

print("Our mean squared error is:", mean_squared_error(diabetes_Y_test, diabetes_Y_predicted))

print("Weight:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - Age
#       - Sex
#       - Body mass index
#       - Average blood pressure
#       - S1
#       - S2
#       - S3
#       - S4
#       - S5
#       - S6
#
# ...

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

#Loading datasets

diabetes = datasets.load_diabetes()

#print(diabetes.keys())

#print(diabetes.DESCR)

#Set single feature and index

diabetes_X = diabetes.data[:, np.newaxis, 2]

#Setting training and testing data

diabetes_X_train = diabetes_X[:-30]
diabetes_X_test = diabetes_X[-30:]

diabetes_Y_train = diabetes.target[:-30]
diabetes_Y_test = diabetes.target[-30:]

#Making linear model

model = linear_model.LinearRegression()

#Fitting model

model.fit(diabetes_X_train, diabetes_Y_train)

#Predicting

diabetes_Y_predicted = model.predict(diabetes_X_test)

#Getting MSE

print("Our mean squared error is:", mean_squared_error(diabetes_Y_test, diabetes_Y_predicted))

print("Weight:", model.coef_)
print("Intercept:", model.intercept_)

plt.scatter(diabetes_X_test, diabetes_Y_test)

#Plotting best fit line
plt.plot(diabetes_X_test, diabetes_Y_predicted)
plt.grid()
plt.show()
# Out:
# Our mean squared error is: 3035.0601152912695
# Weight: [941.43097333]
# Intercept: 153.39713623331698

# %% [markdown]
# ## A simple example of LR:

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

#Set single feature and index

X = np.array([[1],[2],[3]])

#Setting training and testing data

X_train = diabetes_X
X_test = diabetes_X

Y_train = np.array([[3],[2],[4]])
Y_test = np.array([[3],[2],[4]])

#Making linear model

model = linear_model.LinearRegression()

#Fitting model

model.fit(X_train, Y_train)

#Predicting

Y_predicted = model.predict(X_test)

#Getting MSE

print("Our mean squared error is:", mean_squared_error(Y_test, Y_predicted))

print("Weight:", model.coef_)
print("Intercept:", model.intercept_)

plt.scatter(X_test, Y_test)

#Plotting best fit line

plt.plot(X_test, Y_predicted)

plt.grid()
plt.show()
# Out:
# Our mean squared error is: 0.5000000000000001
# Weight: [[0.5]]
# Intercept: [2.]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

#Loading datasets

diabetes = datasets.load_diabetes()

#print(diabetes.keys())

#print(diabetes.DESCR)

#Set single feature and index

diabetes_X = diabetes.data

#Setting training and testing data

diabetes_X_train = diabetes_X
diabetes_X_test = diabetes_X

diabetes_Y_train = diabetes.target
diabetes_Y_test = diabetes.target

#Making linear model

model = linear_model.LinearRegression()

#Fitting model

model.fit(diabetes_X_train, diabetes_Y_train)

#Predicting

diabetes_Y_predicted = model.predict(diabetes_X_test)

#Getting MSE

print("Our mean squared error is:", mean_squared_error(diabetes_Y_test, diabetes_Y_predicted))

print("Weight:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Our mean squared error is: 2859.6903987680657
# Weight: [ -10.01219782 -239.81908937  519.83978679  324.39042769 -792.18416163
#   476.74583782  101.04457032  177.06417623  751.27932109   67.62538639]
# Intercept: 152.1334841628965

# %%
plt.scatter(diabetes_Y_test, diabetes_X_test[:,1])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,2])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,3])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,4])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,5])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,6])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,7])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,8])
plt.scatter(diabetes_Y_test, diabetes_X_test[:,9])

plt.show()
